# %% [markdown]
# ## Welcome to the Official KoboldCpp Colab Notebook
# It's really easy to get started. Just press the two **Play** buttons below, and then connect to the **Cloudflare URL** shown at the end.
# You can select a model from the dropdown, or enter a **custom URL** to a GGUF model (Example: `https://huggingface.co/KoboldAI/LLaMA2-13B-Tiefighter-GGUF/resolve/main/LLaMA2-13B-Tiefighter.Q4_K_M.gguf`)
#
# **Keep this page open and occationally check for captcha's so that your AI is not shut down**

# %%
#@title <-- Tap this if you play on Mobile { display-mode: "form" }
# %%html
<b>Press play on the music player to keep the tab alive, then start KoboldCpp below</b><br/>
<audio autoplay="" src="https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a" loop controls>

# %%
#@title <b>v-- Enter your model below and then click this to start Koboldcpp</b>

# Model = "https://huggingface.co/KoboldAI/LLaMA2-13B-Tiefighter-GGUF/resolve/main/LLaMA2-13B-Tiefighter.Q4_K_M.gguf" #@param ["https://huggingface.co/KoboldAI/LLaMA2-13B-Tiefighter-GGUF/resolve/main/LLaMA2-13B-Tiefighter.Q4_K_M.gguf","https://huggingface.co/Sao10K/Fimbulvetr-11B-v2-GGUF/resolve/main/Fimbulvetr-11B-v2-Test-14.q4_K_M.gguf","https://huggingface.co/TheBloke/MythoMax-L2-13B-GGUF/resolve/main/mythomax-l2-13b.Q4_K_M.gguf","https://huggingface.co/TheBloke/ReMM-SLERP-L2-13B-GGUF/resolve/main/remm-slerp-l2-13b.Q4_K_M.gguf","https://huggingface.co/TheBloke/Xwin-LM-13B-v0.2-GGUF/resolve/main/xwin-lm-13b-v0.2.Q4_K_M.gguf","https://huggingface.co/TheBloke/Stheno-L2-13B-GGUF/resolve/main/stheno-l2-13b.Q4_K_M.gguf","https://huggingface.co/TheBloke/MythoMax-L2-Kimiko-v2-13B-GGUF/resolve/main/mythomax-l2-kimiko-v2-13b.Q4_K_M.gguf","https://huggingface.co/TheBloke/airoboros-mistral2.2-7B-GGUF/resolve/main/airoboros-mistral2.2-7b.Q4_K_S.gguf","https://huggingface.co/afrideva/phi-2-uncensored-GGUF/resolve/main/phi-2-uncensored.q3_k_m.gguf"]{allow-input: true}
# Model = "https://huggingface.co/TheBloke/SOLAR-10.7B-Instruct-v1.0-uncensored-GGUF/resolve/main/solar-10.7b-instruct-v1.0-uncensored.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/SOLAR-10.7B-Instruct-v1.0-GGUF/resolve/main/solar-10.7b-instruct-v1.0.Q8_0.gguf"

Model = "https://huggingface.co/google/gemma-2b-it-GGUF/resolve/main/gemma-2b-it.gguf"

# Model = "https://huggingface.co/rahuldshetty/gemma-7b-it-gguf-quantized/resolve/main/gemma-7b-it-Q8_0.gguf"


# Model = "https://huggingface.co/MaziyarPanahi/gemma-2b-it-GGUF/resolve/main/gemma-2b-it.Q8_0.gguf"

#Model = "https://huggingface.co/lmstudio-ai/gemma-2b-it-GGUF/resolve/main/gemma-2b-it-q8_0.gguf"

# Model = "https://huggingface.co/microsoft/Phi-3-mini-4k-instruct-gguf/resolve/main/Phi-3-mini-4k-instruct-fp16.gguf"

# Model = "https://huggingface.co/lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF/resolve/main/Meta-Llama-3-8B-Instruct-Q8_0.gguf"

# Model = "https://huggingface.co/lmstudio-community/Phi-3-mini-4k-instruct-GGUF/resolve/main/Phi-3-mini-4k-instruct-Q8_0.gguf"



# Model = "https://huggingface.co/TheBloke/Orca-2-13B-GGUF/resolve/main/orca-2-13b.Q8_0.gguf"



# Model = "https://huggingface.co/MaziyarPanahi/zephyr-7b-gemma-v0.1-GGUF/resolve/main/zephyr-7b-gemma-v0.1.Q8_0.gguf"

# Model = "https://huggingface.co/LoneStriker/zephyr-7b-gemma-sft-v0.1-GGUF/resolve/main/zephyr-7b-gemma-sft-v0.1-Q8_0.gguf"

# Model = "https://huggingface.co/MaziyarPanahi/zephyr-7b-gemma-sft-v0.1-GGUF/resolve/main/zephyr-7b-gemma-sft-v0.1.Q8_0.gguf"

# Model = "https://huggingface.co/Isaak-Carter/dolphin-2.8-gemma-2b_gguf/resolve/main/dolphin-2.8-gemma-2b.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/CodeLlama-7B-Instruct-GGUF/resolve/main/codellama-7b-instruct.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/openchat-3.5-0106-GGUF/resolve/main/openchat-3.5-0106.Q8_0.gguf"


# Model = "https://huggingface.co/gguf/openchat-3.5-0106-gemma-GGUF/resolve/main/openchat-3.5-0106-gemma.Q8_0.gguf"


# Model = "https://huggingface.co/pi-null-mezon/openchat-3.5-0106-gemma-GGUF/resolve/main/ggml-model-Q8_0.gguf"


# Model = "https://huggingface.co/mradermacher/Eurus-7b-sft-GGUF/resolve/main/Eurus-7b-sft.Q8_0.gguf"


# Model = "https://huggingface.co/MaziyarPanahi/Mixtral-8x22B-v0.1-GGUF/resolve/main/Mixtral-8x22B-v0.1.Q8_0-00002-of-00005.gguf"



# Model = "https://huggingface.co/mradermacher/Mixtral-8x22B-v0.1-GGUF/resolve/main/Mixtral-8x22B-v0.1.Q8_0.gguf"

# Model = "https://huggingface.co/mradermacher/Mixtral-8x22B-v0.1-GGUF/resolve/main/Mixtral-8x22B-v0.1.Q8_0.gguf.part4of4"


# Model = "https://huggingface.co/mradermacher/Eurus-RM-7b-GGUF/resolve/main/Eurus-RM-7b.Q8_0.gguf"


# Model = "https://huggingface.co/TheBloke/openchat-3.5-1210-GGUF/resolve/main/openchat-3.5-1210.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/zephyr-7B-beta-GGUF/resolve/main/zephyr-7b-beta.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/Dolphin-Llama2-7B-GGUF/resolve/main/dolphin-llama2-7b.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/dolphin-2.6-mistral-7B-dpo-laser-GGUF/resolve/main/dolphin-2.6-mistral-7b-dpo-laser.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/Dolphin2.1-OpenOrca-7B-GGUF/resolve/main/dolphin2.1-openorca-7b.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/Mistral-7B-OpenOrca-GGUF/resolve/main/mistral-7b-openorca.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/Dolphin-Llama2-7B-GGUF/resolve/main/dolphin-llama2-7b.Q8_0.gguf"

# Model =  "https://huggingface.co/TheBloke/claude2-alpaca-7B-GGUF/resolve/main/claude2-alpaca-7b.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/dolphin-2.5-mixtral-8x7b-GGUF/resolve/main/dolphin-2.5-mixtral-8x7b.Q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/Llama-2-7b-Chat-GGUF/resolve/main/llama-2-7b-chat.Q8_0.gguf"

# Model = "https://huggingface.co/afrideva/bloomz-Alpaca-560M-GGUF/resolve/main/bloomz-alpaca-560m.q8_0.gguf"

# Model = "https://huggingface.co/TheBloke/Yi-34B-Chat-GGUF/resolve/main/yi-34b-chat.Q8_0.gguf"


# Model = "https://huggingface.co/TheBloke/dolphin-2.1-mistral-7B-GGUF/resolve/main/dolphin-2.1-mistral-7b.Q8_0.gguf"


Layers = 99 #@param [99]{allow-input: true}
ContextSize = 4096 #@param [4096] {allow-input: true}
ForceRebuild = False #@param {type:"boolean"}
LoadImageModel = False
SDModel = ""
SDCommand = ""

import os
if not os.path.isfile("/opt/bin/nvidia-smi"):
  raise RuntimeError("⚠️Colab did not give you a GPU due to usage limits, this can take a few hours before they let you back in. Check out https://lite.koboldai.net for a free alternative (that does not provide an API link but can load KoboldAI saves and chat cards) or subscribe to Colab Pro for immediate access.⚠️")

# %cd /content
# !git clone https://github.com/LostRuins/koboldcpp
# %cd /content/koboldcpp
kvers = !(cat koboldcpp.py | grep 'KcppVersion = ' | cut -d '"' -f2)
kvers = kvers[0]
if ForceRebuild:
  kvers = "force_rebuild"
if SDModel and LoadImageModel:
  SDCommand = "--sdconfig sdmodel.safetensors clamped 4 quant"
else:
  SDCommand = ""
# !echo Finding prebuilt binary for {kvers}
# !wget -O dlfile.tmp https://kcpplinux.concedo.workers.dev/?{kvers} && mv dlfile.tmp koboldcpp_linux
# !test -f koboldcpp_linux && echo Download Successful || echo Download Failed
# !chmod +x ./koboldcpp_linux
# !apt update
# !apt install aria2 -y
# simple fix for a common URL mistake
if "https://huggingface.co/" in Model and "/blob/main/" in Model:
    Model = Model.replace("/blob/main/", "/resolve/main/")
# !aria2c -x 10 -o model.gguf --summary-interval=5 --download-result=default --allow-overwrite=true --file-allocation=none $Model
# if VCommand:
# !echo Finding prebuilt binary for {kvers}
# !wget -O dlfile.tmp https://kcppcolab.concedo.workers.dev/?{kvers} && mv dlfile.tmp koboldcpp_linux
# # koboldcpp_linux
# # koboldcpp_cublas.so
# !test -f koboldcpp_linux && echo Prebuilt Binary Exists || echo Prebuilt Binary Does Not Exist
# !test -f koboldcpp_linux && echo Build Skipped || make koboldcpp_cublas LLAMA_CUBLAS=1 LLAMA_COLAB=1 LLAMA_PORTABLE=1
# !cp koboldcpp_cublas.so koboldcpp_cublas.dat
# !apt-get install libc-ares2
# !apt install aria2 -y
# !aria2c -x 10 -o model.gguf --summary-interval=5 --download-result=default --allow-overwrite=true --file-allocation=none $Model
if SDCommand:
  # !aria2c -x 10 -o sdmodel.safetensors --summary-interval=5 --download-result=default --allow-overwrite=true --file-allocation=none $SDModel
# !python koboldcpp.py model.gguf --usecublas 0 mmq --multiuser --gpulayers $Layers --contextsize $ContextSize --quiet --remotetunnel $SDCommand
# !./koboldcpp_linux model.gguf --usecublas 0 mmq --multiuser --gpulayers $Layers --contextsize $ContextSize --quiet --remotetunnel $SDCommand
